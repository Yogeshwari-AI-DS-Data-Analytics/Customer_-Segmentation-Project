# %%
import pandas as pd
df = pd.read_csv("Mall_Customers.csv")
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print("Data Ready!")
# Out:
# Data Ready!

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters=5, random_state=42)
df['Segment'] = model.fit_predict(X_scaled)

print(df['Segment'].value_counts())
# Out:
# C:\Users\sakth\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\sakth\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\sakth\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\sakth\AppData\Local\Programs\Python\Python311\Lib\subprocess.py", line 546, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sakth\AppData\Local\Programs\Python\Python311\Lib\subprocess.py", line 1022, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\sakth\AppData\Local\Programs\Python\Python311\Lib\subprocess.py", line 1491, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Segment
# 0    81
# 1    39
# 3    35
# 4    23
# 2    22
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,6))
sns.scatterplot(data=df, 
                x='Annual Income (k$)', 
                y='Spending Score (1-100)', 
                hue='Segment', 
                palette='tab10')
plt.title("Customer Segments")
plt.show()

# %%
df.to_csv("segmentation_result.csv", index=False)
print("Project Complete! File Saved!")
# Out:
# Project Complete! File Saved!
